# %%
import os

import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rc('font', size=16)

# %%
MOPO_PROGRESS_PATH = "ray_mopo/halfcheetah/halfcheetah_medium_replay_101e3/seed:1443_2022-05-11_12-43-30uimp9cp_/progress.csv"

# %%
mopo_progress = pd.read_csv(MOPO_PROGRESS_PATH)
mopo_progress
# Out:
#         Q-avg       Q-std     Q_loss     alpha  policy/shifts-mean  \
# 0    9.383132    8.192502   3.990437  0.737972            0.050151
# 1   16.517096   13.654895   3.089154  0.547772           -0.046026
# 2   18.284012   17.565619   4.222320  0.410513           -0.004789
# 3   16.770760   21.426571   5.748623  0.312032           -0.008929
# 4   11.798985   24.977926   5.363554  0.240589           -0.086694
# ..        ...         ...        ...       ...                 ...
# 65  87.944260  109.901237   9.356260  0.198976           -0.071454
# 66  73.678131  123.303810   9.071168  0.195460           -0.105812
# 67  92.122162  115.491737   6.293514  0.194552           -0.034199
# 68  82.018524  124.282532  12.442011  0.192618           -0.002875
# 69  85.905334  118.355293  10.547335  0.197039            0.000620
#
#     policy/shifts-std  policy/log_scale_diags-mean  \
# 0            0.334215                    -0.166797
# 1            0.378307                    -0.174862
# ...

# %%
feature = 'Q-avg'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(mopo_progress['timesteps_total'], mopo_progress[feature])
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
# Out:
# Text(0, 0.5, 'Q-avg')

# %%
feature = 'evaluation/return-average'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(mopo_progress['timesteps_total'], mopo_progress[feature])
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
# Out:
# Text(0, 0.5, 'evaluation/return-average')

# %%
feature = 'alpha'
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(mopo_progress['timesteps_total'], mopo_progress[feature])
ax.set_xlabel('Steps')
ax.set_ylabel(feature)
# Out:
# Text(0, 0.5, 'alpha')
